# %%
# To display graphs in this notebook, run this:
# %matplotlib inline

# We're now going to import some important libraries

import numpy.random # for generating a noisy data set
from sklearn import linear_model # for training a linear model

import matplotlib.pyplot # for plotting in general
from math import log
import math

import pandas as pd

# %%
#Load Data
data = pd.read_csv("kmer_graphs_data.csv")
data
# Out:
#     Unnamed: 0   k  Number of Distinct k-mers                  4^k  \
# 0            0   1                          2                    4
# 1            1   2                         10                   16
# 2            2   3                         32                   64
# 3            3   4                        136                  256
# 4            4   5                        512                 1024
# 5            5   6                       2013                 4096
# 6            6   7                      24940                16384
# 7            7   8                      59830                65536
# 8            8   9                      23904               262144
# 9            9  10                      16200              1048576
# 10          10  11                      29784              4194304
# 11          11  12                      29813             16777216
# 12          12  13                      29605             67108864
# 13          13  14                      44375            268435456
# 14          14  15                      19881           1073741824
# 15          15  16                      29864           4294967296
# 16          16  17                      39470          17179869184
# 17          17  18                      22385          68719476736
# 18          18  19                       8238         274877906944
# 19          19  20                      29871        1099511627776
# 20          20  21                      35516        4398046511104
# 21          21  22                      35556       17592186044416
# 22          22  23                      28162       70368744177664
# 23          23  24                      24882      281474976710656
# 24          24  25                      27371     1125899906842624
# 25          25  26                      27373     4503599627370496
# 26          26  27                      27372    18014398509481984
# 27          27  28                       9602    72057594037927936
# 28          28  29                       7564   288230376151711744
# 29          29  30                      29862  1152921504606846976
# 30          30  31                      29863  4611686018427387904
#
#     Estimated k-mers
# 0              29971
# 1              29970
# 2              29969
# 3              29968
# 4              29967
# 5              29966
# 6              29965
# 7              29964
# 8              29963
# 9              29962
# 10             29961
# 11             29960
# 12             29959
# 13             29958
# 14             29957
# 15             29956
# 16             29955
# 17             29954
# 18             29953
# 19             29952
# 20             29951
# 21             29950
# 22             29949
# 23             29948
# 24             29947
# 25             29946
# 26             29945
# 27             29944
# 28             29943
# 29             29942
# 30             29941

# %%
#Define Values
k = list(data['k'])

#Estimated K-Mers from len(genome)-k+1
eskmers =

# %%
#Make Log graph
